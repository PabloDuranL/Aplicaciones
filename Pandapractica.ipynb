# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
data=pd.Series([3,5,2,6])
data,data.values,data.index
# Out:
# (0    3
#  1    5
#  2    2
#  3    6
#  dtype: int64,
#  array([3, 5, 2, 6]),
#  RangeIndex(start=0, stop=4, step=1))

# %%
data[1],data[1:3], data[:-1]
# Out:
# (np.int64(5),
#  1    5
#  2    2
#  dtype: int64,
#  0    3
#  1    5
#  2    2
#  dtype: int64)

# %%
data=pd.Series([3,5,2,6], index=['messi','ronaldo','ilya','lasha'])
data['messi']
# Out:
# np.int64(3)

# %%
xd={'messi':5,'ilya':56,'lasha':45}
data=pd.Series(xd)
data, data['messi']
# Out:
# (messi     5
#  ilya     56
#  lasha    45
#  dtype: int64,
#  np.int64(5))

# %%
data['messi':'ilya']
# Out:
# messi     5
# ilya     56
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 1])
# Out:
# 3    c
# 1    b
# dtype: object

# %%
snatch={'ilya':198,'lasha':225,'nassar':188,'pablo':105}
cleanandjerk={'ilya':262,'lasha':267,'nassar':228,'pablo':120}

a=pd.Series(snatch)
b=pd.Series(cleanandjerk)
marcas=pd.DataFrame({'mejor snatch':snatch, 'mejor envion':cleanandjerk})
marcas, marcas.index, marcas.columns
# Out:
# (        mejor snatch  mejor envion
#  ilya             198           262
#  lasha            225           267
#  nassar           188           228
#  pablo            105           120,
#  Index(['ilya', 'lasha', 'nassar', 'pablo'], dtype='object'),
#  Index(['mejor snatch', 'mejor envion'], dtype='object'))

# %%
marcas['mejor snatch']
# Out:
# ilya      198
# lasha     225
# nassar    188
# pablo     105
# Name: mejor snatch, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23716/1499820875.py in <cell line: 0>()
# ----> 1 marcas['col0']
#
# ...
