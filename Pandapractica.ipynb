# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloDuranL/Aplicaciones/blob/main/Pandapractica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %%
data=pd.Series([3,5,2,6])
data,data.values,data.index
# Out:
# (0    3
#  1    5
#  2    2
#  3    6
#  dtype: int64,
#  array([3, 5, 2, 6]),
#  RangeIndex(start=0, stop=4, step=1))

# %%
data[1],data[1:3], data[:-1]
# Out:
# (np.int64(5),
#  1    5
#  2    2
#  dtype: int64,
#  0    3
#  1    5
#  2    2
#  dtype: int64)

# %%
data=pd.Series([3,5,2,6], index=['messi','ronaldo','ilya','lasha'])
data['messi'],data
# Out:
# (np.int64(3),
#  messi      3
#  ronaldo    5
#  ilya       2
#  lasha      6
#  dtype: int64)

# %%
xd={'messi':5,'ilya':56,'lasha':45}
data=pd.Series(xd)
data, data['messi']
# Out:
# (messi     5
#  ilya     56
#  lasha    45
#  dtype: int64,
#  np.int64(5))

# %%
data['messi':'ilya']
# Out:
# messi     5
# ilya     56
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[1,2,3])
# Out:
# 1    b
# 2    a
# 3    c
# dtype: object

# %%
snatch_dict={'ilya':198,'lasha':225,'nassar':188,'pablo':105}
cleanandjerk_dict={'ilya':262,'lasha':267,'nassar':228,'pablo':120}

snatch=pd.Series(snatch_dict)
cleanandjerk=pd.Series(cleanandjerk_dict)
marcas=pd.DataFrame({'mejor snatch':snatch_dict, 'mejor envion':cleanandjerk_dict})
marcas, marcas.index, marcas.columns
# Out:
# (        mejor snatch  mejor envion
#  ilya             198           262
#  lasha            225           267
#  nassar           188           228
#  pablo            105           120,
#  Index(['ilya', 'lasha', 'nassar', 'pablo'], dtype='object'),
#  Index(['mejor snatch', 'mejor envion'], dtype='object'))

# %%
marcas['mejor snatch']
# Out:
# ilya      198
# lasha     225
# nassar    188
# pablo     105
# Name: mejor snatch, dtype: int64

# %%
pd.DataFrame(snatch,columns=['mejor snatch'])
# Out:
#         mejor snatch
# ilya             198
# lasha            225
# nassar           188
# pablo            105

# %%
data = [{'a': i, 'b': 2 * i}
        for i in range(6)]
pd.DataFrame(data)
# Out:
#    a   b
# 0  0   0
# 1  1   2
# 2  2   4
# 3  3   6
# 4  4   8
# 5  5  10

# %%
pd.DataFrame([{'a': 1, 'b': 2}, {'b': 3, 'c': 4}], index=[9,3])
# Out:
#      a  b    c
# 9  1.0  2  NaN
# 3  NaN  3  4.0

# %%
x=np.random.randint(100,200, size=(4,3))
x
# Out:
# array([[180, 189, 158],
#        [196, 192, 168],
#        [188, 124, 178],
#        [106, 180, 139]])

# %%
resultados=pd.DataFrame(x,columns=['arr','env','sent'], index=['pablo','lasha','ilya','klokov'])

# %%
resultados['total']= resultados['arr']+resultados['env']
resultados
# Out:
#         arr  env  sent  total
# pablo   180  189   158    369
# lasha   196  192   168    388
# ilya    188  124   178    312
# klokov  106  180   139    286

# %%
resultados.loc['ilya']
# Out:
# arr      188
# env      124
# sent     178
# total    312
# Name: ilya, dtype: int64

# %%
resultados - resultados.loc['ilya']
# Out:
#         arr  env  sent  total
# pablo    -8   65   -20     57
# lasha     8   68   -10     76
# ilya      0    0     0      0
# klokov  -82   56   -39    -26

# %%
ind = pd.Index([2,3])
ind
# Out:
# Index([2, 3], dtype='int64')

# %%
edad_d={'sally':2,'pucca':6}
peso_d={'sally':7, 'pucca':15}
edad=pd.Series(edad_d)
peso=pd.Series(peso_d)
pd.DataFrame({'edad':edad_d,'peso':peso_d})
# Out:
#        edad  peso
# sally     2     7
# pucca     6    15

# %%
resultados.iloc[0:2]
# Out:
#        arr  env  sent  total
# pablo  180  189   158    369
# lasha  196  192   168    388

# %%
resultados.iloc[0]
# Out:
# arr      180
# env      189
# sent     158
# total    369
# Name: pablo, dtype: int64

# %%
resultados.loc[resultados.arr>150,'env']
# Out:
# pablo    189
# lasha    192
# ilya     124
# Name: env, dtype: int64

# %%
resultados.loc[resultados.arr>150,['total','sent']]
# Out:
#        total  sent
# pablo    369   158
# lasha    388   168
# ilya     312   178

# %%
resultados.iloc[0,3]=200
resultados
# Out:
#         arr  env  sent  total
# pablo   180  189   158    200
# lasha   196  192   168    388
# ilya    188  124   178    312
# klokov  106  180   139    286

# %%
resultados.loc[::2,['total','sent']]=[200,209]
resultados
# Out:
#         arr  env  sent  total
# pablo   180  189   209    200
# lasha   196  192   168    388
# ilya    188  124   209    200
# klokov  106  180   139    286

# %%
df = pd.DataFrame(np.random.randint(0, 10, size=(3, 4)),
                  columns=list('ABCD'))
df
# Out:
#    A  B  C  D
# 0  6  3  5  5
# 1  9  5  7  5
# 2  8  5  8  0

# %%
rng=np.random.RandomState(4)
rng.randint(150,200)
# Out:
# 196

# %%
df = pd.DataFrame([[1,      np.nan, 2],
                   [2,      3,      5],
                   [np.nan, 4,      6]])
df

df.dropna(axis='columns')
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
x=np.random.rand(3,3)
y=np.random.rand(3)
np.hstack((x, y[:, np.newaxis]))
np.vstack((x,y)), y[:,np.newaxis].shape
# Out:
# (array([[0.15268427, 0.88152486, 0.30546318],
#         [0.2794066 , 0.80693323, 0.68288056],
#         [0.35268135, 0.8988825 , 0.99491749],
#         [0.73615651, 0.54144185, 0.22026012]]),
#  (3, 1))

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(6)
# Out:
# a    1.0
# b    6.0
# c    2.0
# d    6.0
# e    3.0
# dtype: float64

# %%
data.fillna(method='ffill')
# Out:
# /tmp/ipykernel_11355/1844443866.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
data.fillna(method='bfill')
# Out:
# /tmp/ipykernel_11355/1397359497.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.fillna(method='ffill', axis=0)
# Out:
# /tmp/ipykernel_11355/3122255136.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=0)
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  2.0  4.0  6

# %%
df.dropna()
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
index=[('ilya',2008),('ilya',2012)]
snatch=np.array([345,367])
envion=np.array([343,345])
marcas=[snatch,envion]
df = pd.DataFrame(marcas, index=index) # Create DataFrame with default column names
df.columns = ['Mejor total','Mejor envion'] # Assign desired column names
df
# Out:
#               Mejor total  Mejor envion
# (ilya, 2008)          345           367
# (ilya, 2012)          343           345

# %%
index = pd.MultiIndex.from_tuples(index)
index
df.reindex(index)
# Out:
#            Mejor total  Mejor envion
# ilya 2008          345           367
#      2012          343           345

# %%
index = [('California', 2000), ('California', 2010),
         ('New York', 2000), ('New York', 2010),
         ('Texas', 2000), ('Texas', 2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %%
pop[('California',2000):('New York',2010)]
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# dtype: int64

# %%
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )

# %%
pop = pop.reindex(index)
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop[:, 2010]
# Out:
# California    37253956
# New York      19378102
# Texas         25145561
# dtype: int64

# %%
pop_df=pop.unstack()
pop_df
# Out:
#                 2000      2010
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop_df.stack()
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop_df = pd.DataFrame({'total': pop,
                       'under18': [9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})
pop_df
# Out:
#                     total  under18
# California 2000  33871648  9267089
#            2010  37253956  9284094
# New York   2000  18976457  4687374
#            2010  19378102  4318033
# Texas      2000  20851820  5906301
#            2010  25145561  6879014

# %%
f_u18 = pop_df['under18'] / pop_df['total']
f_u18
# Out:
# California  2000    0.273594
#             2010    0.249211
# New York    2000    0.247010
#             2010    0.222831
# Texas       2000    0.283251
#             2010    0.273568
# dtype: float64

# %%
f_u18.unstack()
# Out:
#                 2000      2010
# California  0.273594  0.249211
# New York    0.247010  0.222831
# Texas       0.283251  0.273568

# %%
df = pd.DataFrame(np.random.rand(4, 2),
                  index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                  columns=['data1', 'data2'])
df
# Out:
#         data1     data2
# a 1  0.193403  0.699347
#   2  0.777918  0.435475
# b 1  0.605903  0.960217
#   2  0.238377  0.105228

# %%
data = {('California', 2000): 33871648,
        ('California', 2010): 37253956,
        ('Texas', 2000): 20851820,
        ('Texas', 2010): 25145561,
        ('New York', 2000): 18976457,
        ('New York', 2010): 19378102}
pd.Series(data)
